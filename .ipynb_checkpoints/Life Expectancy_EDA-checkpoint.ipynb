# %%
import pandas as pd
import numpy as np
import seaborn as sns
import datetime
import scipy
import matplotlib.pyplot as plt

sns.set_style('darkgrid')
plt.rcParams['font.size'] = 14
plt.rcParams['figure.figsize'] = (12, 6)

# %matplotlib inline

# %% [markdown]
# # Understanding and cleaning our Dataset
#
# ### undertanding our dataset

# %%
#### Importing the dataset
data = pd.read_csv('Life Expectancy Data.csv')
#Displaying the data
data
# Out:
#           Country  Year      Status  Life expectancy   Adult Mortality  \
# 0     Afghanistan  2015  Developing              65.0            263.0
# 1     Afghanistan  2014  Developing              59.9            271.0
# 2     Afghanistan  2013  Developing              59.9            268.0
# 3     Afghanistan  2012  Developing              59.5            272.0
# 4     Afghanistan  2011  Developing              59.2            275.0
# ...           ...   ...         ...               ...              ...
# 2933     Zimbabwe  2004  Developing              44.3            723.0
# 2934     Zimbabwe  2003  Developing              44.5            715.0
# 2935     Zimbabwe  2002  Developing              44.8             73.0
# 2936     Zimbabwe  2001  Developing              45.3            686.0
# 2937     Zimbabwe  2000  Developing              46.0            665.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# ...

# %% [markdown]
# from above we see that our dataset is made of 2938 rows and 22 columns

# %%
#understanding our columns labels better
data.columns
# Out:
# Index(['Country', 'Year', 'Status', 'Life expectancy ', 'Adult Mortality',
#        'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
#        'Measles ', ' BMI ', 'under-five deaths ', 'Polio', 'Total expenditure',
#        'Diphtheria ', ' HIV/AIDS', 'GDP', 'Population',
#        ' thinness  1-19 years', ' thinness 5-9 years',
#        'Income composition of resources', 'Schooling'],
#       dtype='object')

# %% [markdown]
# Here we spotted that some of our columns are lebelled with spaces in between and some have spaces after them.
# so we have to be carely when typing them else it will give us headeache :)

# %% [markdown]
# ### Narrowing down our cloumns to only the feilds of interest
# + Country
# + Year
# + Status
# + Life expectancy
# + Hepatitis B
# + Polio
# + Diphtheria
# + Schooling

# %%
#Getting our interested feilds
selected_columns = ['Country', 'Year', 'Status', 'Life expectancy ', 'Hepatitis B', 
       'Polio', 'Diphtheria ', 'Schooling']

# %%
new_data = data[selected_columns].copy()

# %%
new_data
# Out:
#           Country  Year      Status  Life expectancy   Hepatitis B  Polio  \
# 0     Afghanistan  2015  Developing              65.0         65.0    6.0
# 1     Afghanistan  2014  Developing              59.9         62.0   58.0
# 2     Afghanistan  2013  Developing              59.9         64.0   62.0
# 3     Afghanistan  2012  Developing              59.5         67.0   67.0
# 4     Afghanistan  2011  Developing              59.2         68.0   68.0
# ...           ...   ...         ...               ...          ...    ...
# 2933     Zimbabwe  2004  Developing              44.3         68.0   67.0
# 2934     Zimbabwe  2003  Developing              44.5          7.0    7.0
# 2935     Zimbabwe  2002  Developing              44.8         73.0   73.0
# 2936     Zimbabwe  2001  Developing              45.3         76.0   76.0
# 2937     Zimbabwe  2000  Developing              46.0         79.0   78.0
#
#       Diphtheria   Schooling
# 0            65.0       10.1
# ...

# %% [markdown]
# Our dataset is now made up 2938 rows and 7 columns

# %%
new_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Country           2938 non-null   object
#  1   Year              2938 non-null   int64
#  2   Status            2938 non-null   object
#  3   Life expectancy   2928 non-null   float64
#  4   Hepatitis B       2385 non-null   float64
#  5   Polio             2919 non-null   float64
#  6   Diphtheria        2919 non-null   float64
#  7   Schooling         2775 non-null   float64
# dtypes: float64(5), int64(1), object(2)
# memory usage: 183.8+ KB

# %% [markdown]
# Here we can see that some of the have missing values
# and we can also see all the values datatypes for instance the year feild is seen as int and status is seen as object

# %% [markdown]
# ### Dealing with Missing Values

# %%
#getting all missing values
new_data.isnull().sum()
# Out:
# Country               0
# Year                  0
# Status                0
# Life expectancy      10
# Hepatitis B         553
# Polio                19
# Diphtheria           19
# Schooling           163
# dtype: int64

# %% [markdown]
# Here we can tell that Hepatitis B has the most missing values
# and Life expectancy has the least

# %%
#getting all the rows that have the missing values
null_values = new_data[new_data.isnull().any(axis=1)]

# %%
#display 50 random 
null_values.sample(50)
# Out:
#                                                 Country  Year      Status  \
# 519                            Central African Republic  2008  Developing
# 1498                                            Liberia  2007  Developing
# 925                                             Finland  2004  Developing
# 2348                                           Slovenia  2012   Developed
# 2093                                  Republic of Korea  2009  Developing
# 1154                                            Hungary  2015   Developed
# 768                                            Djibouti  2000  Developing
# 2614                                        Timor-Leste  2002  Developing
# 2533                                        Switzerland  2003   Developed
# 2612                                        Timor-Leste  2004  Developing
# 2775  United Kingdom of Great Britain and Northern I...  2002   Developed
# 2261                                            Senegal  2003  Developing
# ...

# %% [markdown]
# from above we can tell that the null values is distributed in te dataset so it will be ideal to drop all the null values
# so will be replacing them

# %%
#understand the dataset better
new_data.describe()
# Out:
#               Year  Life expectancy   Hepatitis B        Polio  Diphtheria   \
# count  2938.000000       2928.000000  2385.000000  2919.000000  2919.000000
# mean   2007.518720         69.224932    80.940461    82.550188    82.324084
# std       4.613841          9.523867    25.070016    23.428046    23.716912
# min    2000.000000         36.300000     1.000000     3.000000     2.000000
# 25%    2004.000000         63.100000    77.000000    78.000000    78.000000
# 50%    2008.000000         72.100000    92.000000    93.000000    93.000000
# 75%    2012.000000         75.700000    97.000000    97.000000    97.000000
# max    2015.000000         89.000000    99.000000    99.000000    99.000000
#
#          Schooling
# count  2775.000000
# mean     11.992793
# std       3.358920
# min       0.000000
# 25%      10.100000
# 50%      12.300000
# 75%      14.300000
# max      20.700000

# %% [markdown]
# ###### Handling null values
#
# after observing our dataset we have decided to do replacement
# + for lifeexpectancy
# + Polio
# + Hepatitis B
# \
# using their mean values because the are lower than the 75th percentile and hence won't introduce outliers

# %%
#Replacing null life expectancy with mean
new_data['Life expectancy '].fillna(new_data['Life expectancy '].mean(),inplace=True)

# %%
new_data['Life expectancy '].isnull().sum()
# Out:
# 0

# %%
new_data.describe()
# Out:
#               Year  Life expectancy   Hepatitis B        Polio  Diphtheria   \
# count  2938.000000       2938.000000  2385.000000  2919.000000  2919.000000
# mean   2007.518720         69.224932    80.940461    82.550188    82.324084
# std       4.613841          9.507640    25.070016    23.428046    23.716912
# min    2000.000000         36.300000     1.000000     3.000000     2.000000
# 25%    2004.000000         63.200000    77.000000    78.000000    78.000000
# 50%    2008.000000         72.000000    92.000000    93.000000    93.000000
# 75%    2012.000000         75.600000    97.000000    97.000000    97.000000
# max    2015.000000         89.000000    99.000000    99.000000    99.000000
#
#          Schooling
# count  2775.000000
# mean     11.992793
# std       3.358920
# min       0.000000
# 25%      10.100000
# 50%      12.300000
# 75%      14.300000
# max      20.700000

# %%
#Replacing null Polio with mean
new_data['Polio'].fillna(new_data['Polio'].mean(),inplace=True)

# %%
#confirm if it's replaced
new_data['Polio'].isnull().sum()
# Out:
# 0

# %%
#Replacing null Polio with mean
new_data['Diphtheria '].fillna(new_data['Diphtheria '].mean(),inplace=True)

# %%
#confirm if it's replaced
new_data['Diphtheria '].isnull().sum()
# Out:
# 0

# %%
#Replacing null Hepatitis B with mean
new_data['Hepatitis B'].fillna(new_data['Hepatitis B'].mean(),inplace=True)

# %%
#confirm if it's replaced
new_data['Hepatitis B'].isnull().sum()
# Out:
# 0

# %%
new_data.describe()
# Out:
#               Year  Life expectancy   Hepatitis B        Polio  Diphtheria   \
# count  2938.000000       2938.000000  2938.000000  2938.000000  2938.000000
# mean   2007.518720         69.224932    80.940461    82.550188    82.324084
# std       4.613841          9.507640    22.586855    23.352143    23.640073
# min    2000.000000         36.300000     1.000000     3.000000     2.000000
# 25%    2004.000000         63.200000    80.940461    78.000000    78.000000
# 50%    2008.000000         72.000000    87.000000    93.000000    93.000000
# 75%    2012.000000         75.600000    96.000000    97.000000    97.000000
# max    2015.000000         89.000000    99.000000    99.000000    99.000000
#
#          Schooling
# count  2775.000000
# mean     11.992793
# std       3.358920
# min       0.000000
# 25%      10.100000
# 50%      12.300000
# 75%      14.300000
# max      20.700000

# %%
new_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Country           2938 non-null   object
#  1   Year              2938 non-null   int64
#  2   Status            2938 non-null   object
#  3   Life expectancy   2938 non-null   float64
#  4   Hepatitis B       2938 non-null   float64
#  5   Polio             2938 non-null   float64
#  6   Diphtheria        2938 non-null   float64
#  7   Schooling         2775 non-null   float64
# dtypes: float64(5), int64(1), object(2)
# memory usage: 183.8+ KB

# %%
new_data.isnull().sum()
# Out:
# Country               0
# Year                  0
# Status                0
# Life expectancy       0
# Hepatitis B           0
# Polio                 0
# Diphtheria            0
# Schooling           163
# dtype: int64

# %%
new_data.describe()
# Out:
#               Year  Life expectancy   Hepatitis B        Polio  Diphtheria   \
# count  2938.000000       2938.000000  2938.000000  2938.000000  2938.000000
# mean   2007.518720         69.224932    80.940461    82.550188    82.324084
# std       4.613841          9.507640    22.586855    23.352143    23.640073
# min    2000.000000         36.300000     1.000000     3.000000     2.000000
# 25%    2004.000000         63.200000    80.940461    78.000000    78.000000
# 50%    2008.000000         72.000000    87.000000    93.000000    93.000000
# 75%    2012.000000         75.600000    96.000000    97.000000    97.000000
# max    2015.000000         89.000000    99.000000    99.000000    99.000000
#
#          Schooling
# count  2775.000000
# mean     11.992793
# std       3.358920
# min       0.000000
# 25%      10.100000
# 50%      12.300000
# 75%      14.300000
# max      20.700000

# %% [markdown]
# # Question based on our hypothetis

# %% [markdown]
# ### 1. What is the distribution of countries by their status

# %%
#counts by status
status_counts = country['Status'].value_counts()
status_counts
# Out:
# Developing    161
# Developed      32
# Name: Status, dtype: int64

# %% [markdown]
# from the count above we can see that only 32 countries fall within the developed countries\
# and this is illustrated in the pie chart below

# %%
plt.figure(figsize=(20,10))
plt.title('Status')
plt.pie(status_counts, labels=status_counts.index, autopct='%1.2f%%');

# %% [markdown]
# form above we can clearly see that
# + Only 16.58% of the countries are classified as developed.
# + and 83.42% of the countries are classified as developing

# %% [markdown]
# ### 2. What is the life expectancy trend of  over the years?

# %%
sns.histplot(new_data['Life expectancy '], kde=True)
# Out:
# <AxesSubplot:xlabel='Life expectancy ', ylabel='Count'>

# %% [markdown]
# from the Hisplot above it appears that most countries over the years have their life expectrancy between 65 and 80

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(data=new_data, x=data['Year'], y=data['Life expectancy '])
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Life expectancy '>

# %% [markdown]
# It also appears that life expectancy has been improving over the years.\
# However there was a low growth between 2009 and 2010

# %% [markdown]
# #### 3. What is the average life expectancy in developing and developed countries each year?

# %% [markdown]
# To compute this, we have to group the data frame with status and year.

# %%
# sns.lineplot(data=status, x=status['Year'], y=status['Life expectancy '], hue='Status')
status = round(new_data.groupby(['Status','Year'])['Life expectancy '].mean(), 2)

# %%
status = status.reset_index()

# %%
status.pivot(index='Year', columns='Status')
# Out:
#        Life expectancy
# Status        Developed Developing
# Year
# 2000              76.80      64.62
# 2001              77.13      65.01
# 2002              77.55      65.19
# 2003              77.94      65.21
# 2004              78.38      65.37
# 2005              78.59      66.01
# 2006              79.13      66.45
# 2007              79.30      66.86
# 2008              78.93      67.41
# 2009              79.58      67.89
# 2010              80.15      67.91
# 2011              80.71      68.52
# 2012              80.44      68.90
# 2013              80.68      69.23
# 2014              81.14      69.50
# 2015              80.71      69.69

# %% [markdown]
# As expected, life expectancy of developed nations is greater than developing nations in each year.

# %%
#comparing the life expectancy trend for developed and developing countries over the years
plt.figure(figsize=(12, 6))
sns.lineplot(data=status, x=status['Year'], y=status['Life expectancy '], hue='Status')
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Life expectancy '>

# %% [markdown]
# **Observations**
# we can clearly see that there was has be improvement in both developed and developing countries over the years(2000-2015)\
# however there was a
# + decline in 2008 and 2012 for developed countries
# + decline bewteen 2009 and 2010 for developing countries
# + a slow growth between 2002 and 2004

# %% [markdown]
# ### 4. How do the various immunizations(Hepatitis B, Polio and Diphtheria) relate to life expectancy?

# %%
# using the correlation and heatmap
# calculate correlation
plt.figure(figsize=(12, 6))
corr = new_data.corr()
# plot the heatmap
sns.heatmap(corr, xticklabels=corr.columns,yticklabels=corr.columns, annot=True, cmap="Spectral")
plt.title("Heatmap showing the correlation between variables", fontdict = {'fontsize' : 26});

# %% [markdown]
# **Obervation**
# + There is a weak positive correlation between Life expectancy and Hepatitis B (r=0.2)
# + There is a moderate positive correlation between Life expectancy and Polio (r=0.46)
# + There is a moderate positive correlation between Life expectancy and Diphtheria (r=0.48)
# + There is a stront positive correlation between Life expectancy and Scooling (r=0.75)
#
# so in general we can say that, increase in immunization will improve life expectancy\
# and increase in schooling also contribute to improved life expectancy and vice versa

# %% [markdown]
# ### Q4: Which countries have high life expectancy despite having low schooling?

# %%
new_data.describe()
# Out:
#               Year  Life expectancy   Hepatitis B        Polio  Diphtheria   \
# count  2938.000000       2938.000000  2938.000000  2938.000000  2938.000000
# mean   2007.518720         69.224932    80.940461    82.550188    82.324084
# std       4.613841          9.507640    22.586855    23.352143    23.640073
# min    2000.000000         36.300000     1.000000     3.000000     2.000000
# 25%    2004.000000         63.200000    80.940461    78.000000    78.000000
# 50%    2008.000000         72.000000    87.000000    93.000000    93.000000
# 75%    2012.000000         75.600000    96.000000    97.000000    97.000000
# max    2015.000000         89.000000    99.000000    99.000000    99.000000
#
#          Schooling
# count  2775.000000
# mean     11.992793
# std       3.358920
# min       0.000000
# 25%      10.100000
# 50%      12.300000
# 75%      14.300000
# max      20.700000

# %% [markdown]
# ###### Based on the above we assume that:
# the 75th percentile(75.6) as the requirement for high expectancy\
# the 25th percentile(10.1) as the requirement for low scooling

# %%
high_LE = new_data[new_data['Life expectancy '] > 75 ]

# %%
high_LE_by_schooling = high_LE[high_LE['Schooling'] < 10]

# %%
high_LE_by_schooling.reset_index(inplace=True)

# %%
high_LE_by_schooling[['Country','Life expectancy ', 'Schooling', 'Status']]
# Out:
#       Country  Life expectancy   Schooling      Status
# 0  Bangladesh              77.0        9.9  Developing
# 1     Morocco              77.0        9.8  Developing

# %% [markdown]
# from above we can see that two countries despite having low shooling fall with high expectancy\
# and interestingly they are comin from the developing countries
